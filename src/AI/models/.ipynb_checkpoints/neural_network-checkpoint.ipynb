# %%
import pandas as pd
from datetime import datetime

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2024-01-04 00:43:58.969116: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-04 00:43:58.969189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-04 00:43:58.970776: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-04 00:43:58.978227: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-04 00:43:59.836472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# []
# 2024-01-04 00:44:00.918072: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
df = pd.read_csv('../data/current.csv')
# df = pd.read_csv('../../training_data.csv')
df.head()
df.shape
# Out:
# (4522, 42)

# %% [markdown]
# ### Cleaning

# %%
df.drop(df['skaterFullName'].loc[df['skaterFullName'] == 'Taylor Hall'].index, inplace=True)
df = df.drop(columns=['skaterFullName', 'teamAbbrevs', 'vs', 'shoots', 'row', 'date']) 
df = df.dropna()
df.head()
# Out:
#       ppPoints  gamesPlayed position  ppUnit avgPowerplayToi  team_PEN/GP  \
# 2133         0           16        L     2.0           01:46     4.017515
# 2134         4           24        C     1.0           02:10     4.017515
# 2135         3           26        C     1.0           03:14     4.017515
# 2137         3           26        R     2.0           01:51     4.017515
# 2138         2           26        D     1.0           01:43     4.017515
#
#       team_PP%  team_PK%  team_G  team_GA  ...  PPGF_enemy  PPG/PG_enemy  \
# 2133   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2134   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2135   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2137   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2138   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
#
#       PPO/PG_enemy  PPTOI/PG_enemy  PEN_enemy  PENMin_enemy  \
# 2133       3.29166      305.458333      110.0         258.0
# 2134       3.29166      305.458333      110.0         258.0
# 2135       3.29166      305.458333      110.0         258.0
# 2137       3.29166      305.458333      110.0         258.0
# 2138       3.29166      305.458333      110.0         258.0
#
#       PENSeconds/PG_enemy  PENDrawn/GP_enemy  PPGA_enemy  PKTIO/PG_enemy
# 2133                645.0           4.029789        10.0      368.791666
# 2134                645.0           4.029789        10.0      368.791666
# 2135                645.0           4.029789        10.0      368.791666
# 2137                645.0           4.029789        10.0      368.791666
# 2138                645.0           4.029789        10.0      368.791666
#
# [5 rows x 36 columns]

# %%
df['avgPowerplayToi'] = df['avgPowerplayToi'].apply(lambda x: datetime.strptime(str(x), "%M:%S").second + datetime.strptime(str(x), "%M:%S").minute * 60)


df['position'].replace(['C', 'R', 'L', 'D'], [2, 2, 2, 1], inplace=True)
df.head()
# Out:
#       ppPoints  gamesPlayed  position  ppUnit  avgPowerplayToi  team_PEN/GP  \
# 2133         0           16         2     2.0              106     4.017515
# 2134         4           24         2     1.0              130     4.017515
# 2135         3           26         2     1.0              194     4.017515
# 2137         3           26         2     2.0              111     4.017515
# 2138         2           26         1     1.0              103     4.017515
#
#       team_PP%  team_PK%  team_G  team_GA  ...  PPGF_enemy  PPG/PG_enemy  \
# 2133   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2134   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2135   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2137   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
# 2138   0.15789   0.81176    74.0     90.0  ...        18.0          0.75
#
#       PPO/PG_enemy  PPTOI/PG_enemy  PEN_enemy  PENMin_enemy  \
# 2133       3.29166      305.458333      110.0         258.0
# 2134       3.29166      305.458333      110.0         258.0
# 2135       3.29166      305.458333      110.0         258.0
# 2137       3.29166      305.458333      110.0         258.0
# 2138       3.29166      305.458333      110.0         258.0
#
#       PENSeconds/PG_enemy  PENDrawn/GP_enemy  PPGA_enemy  PKTIO/PG_enemy
# 2133                645.0           4.029789        10.0      368.791666
# 2134                645.0           4.029789        10.0      368.791666
# 2135                645.0           4.029789        10.0      368.791666
# 2137                645.0           4.029789        10.0      368.791666
# 2138                645.0           4.029789        10.0      368.791666
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

labels=['scored', 'no-score']

scored = df[df['scored'] == 1]['scored']
no_score = df[df['scored'] == 0]['scored']

concat = pd.concat([scored, no_score])

sns.countplot(x=concat, data=df, palette='hls')
print('Players who scored: ', len(scored))
print('Players who did not score: ', len(no_score))
# Out:
# Players who scored:  418
# Players who did not score:  1912
# C:\Users\Logan\AppData\Local\Temp\ipykernel_25692\326808471.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=concat, data=df, palette='hls')

# %%
perc = (scored.shape[0] / df['scored'].shape[0]) * 100
print(f'Percentage of players with a scored point ({scored.shape[0]}/{df["scored"].shape[0]}): {round(perc, 2)}%')
# Out:
# Percentage of players with a scored point (418/2330): 17.94%

# %% [markdown]
# ### Clustering

# %%
# import pandas as pd
# from sklearn.cluster import KMeans
# from sklearn.metrics import silhouette_score
# from sklearn.preprocessing import StandardScaler

# # Assuming df is your DataFrame containing the sample data
# # df = ...

# # Select the features for clustering
# features = ['ppPoints', 'gamesPlayed', 'position', 'ppUnit', 'avgPowerplayToi', 'team_G', 'team_GA', 'team_PP%', 'PPGF', 'PPG/PG', 'PPO/PG',
#             'PPTOI/PG', 'PEN', 'PENMin', 'team_PEN/GP', 'PENSeconds/PG', 'PENDrawn/GP', 'PPGA', 'team_PK%', 'PKTIO/PG', 'enemy_G', 'enemy_GA', 'enemy_PP%',
#             'PPGF_enemy', 'PPG/PG_enemy', 'PPO/PG_enemy', 'PPTOI/PG_enemy', 'PEN_enemy', 'PENMin_enemy', 'enemy_PEN/GP', 'PENSeconds/PG_enemy', 'PENDrawn/GP_enemy',
#             'PPGA_enemy', 'enemy_PK%', 'PKTIO/PG_enemy']

# # Use StandardScaler to normalize the features
# scaler = StandardScaler()
# df_scaled = pd.DataFrame(scaler.fit_transform(df[features]), columns=features)

# # Choose the number of clusters (you may adjust this based on your data)
# silhouette_scores = []
# for n_clusters in range(2, 12):
#     # Apply K-Means clustering
#     kmeans = KMeans(n_clusters=n_clusters, random_state=42)
#     cluster_labels = kmeans.fit_predict(df_scaled)
    
#     # Calculate the silhouette score
#     silhouette_avg = silhouette_score(df_scaled, cluster_labels)
#     silhouette_scores.append(silhouette_avg)

# n_clusters = silhouette_scores.index(max(silhouette_scores))

# # Apply K-Means clustering
# kmeans = KMeans(n_clusters=n_clusters, random_state=42)
# df['cluster'] = kmeans.fit_predict(df_scaled)

# df.sample(5)

# %% [markdown]
# ### Neural Network

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from keras.callbacks import EarlyStopping

# %%
# from sklearn.model_selection import GridSearchCV
# from keras.wrappers.scikit_learn import KerasClassifier

# # 35 Features
# features = ['ppPoints', 'gamesPlayed', 'position', 'ppUnit', 'avgPowerplayToi', 'team_G', 'team_GA', 'team_PP%', 'PPGF', 'PPG/PG', 'PPO/PG',
#             'PPTOI/PG', 'PEN', 'PENMin', 'team_PEN/GP', 'PENSeconds/PG', 'PENDrawn/GP', 'PPGA', 'team_PK%', 'PKTIO/PG', 'enemy_G', 'enemy_GA', 'enemy_PP%',
#             'PPGF_enemy', 'PPG/PG_enemy', 'PPO/PG_enemy', 'PPTOI/PG_enemy', 'PEN_enemy', 'PENMin_enemy', 'enemy_PEN/GP', 'PENSeconds/PG_enemy', 'PENDrawn/GP_enemy',
#             'PPGA_enemy', 'enemy_PK%', 'PKTIO/PG_enemy']

# # Function to create the model
# def create_model(optimizer='adam', units=256, epochs=65, batch_size=256):
#     model = Sequential()
#     model.add(Dense(units, activation='relu'))
#     model.add(LSTM(units, input_shape=(X_train.shape[1], X_train.shape[2])))
#     model.add(Dense(1, activation='sigmoid'))
#     model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=[tf.keras.metrics.Precision()])
#     return model

# # Create KerasClassifier for use in scikit-learn GridSearchCV
# model = KerasClassifier(build_fn=create_model, verbose=1)

# # Define the hyperparameters to tune
# param_grid = {
#     'optimizer': ['adam', 'rmsprop'],  # Example: Add more optimizers
#     'units': [64, 128, 256],           # Example: Number of units in dense and LSTM layers
#     'epochs': [50, 65, 80],             # Example: Number of training epochs
#     'batch_size': [128, 256, 512],      # Example: Batch size
# }

# scaler = StandardScaler()
# scaler.fit(df[features])
# df[features] = scaler.transform(df[features])

# # df[features] = df[features].apply(lambda x: x + biases[x.name])

# X = df[features].values
# y = df['scored'].values

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
# oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)

# # Fit and transform the training data using the RandomUnderSampler
# # X_train, y_train = undersampler.fit_resample(X_train, y_train)
# X_train, y_train = oversampler.fit_resample(X_train, y_train)

# X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
# X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# # Create GridSearchCV
# grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='precision', cv=3)
# grid_result = grid.fit(X_train, y_train)

# # Summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# # Create a model with the best parameters
# best_params = grid_result.best_params_
# best_model = create_model(
#     optimizer=best_params['optimizer'],
#     units=best_params['units'],
#     epochs=best_params['epochs'],
#     batch_size=best_params['batch_size']
# )

# # Train the best model
# history = best_model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], validation_data=(X_test, y_test), verbose=1, shuffle=True)

# %%
features = ['ppPoints', 'gamesPlayed', 'avgPowerplayToi', 'team_PEN/GP', 'team_PP%', 'team_PK%', 'team_GA', 'team_G', 'enemy_PEN/GP', 'enemy_PP%', 'enemy_PK%', 'enemy_GA', 'enemy_G']

# biases = {
#     'ppPoints': 2.5,
#     'gamesPlayed': 0.5,
#     'avgPowerplayToi': 2.6,
#     'team_PEN/GP': 0.0,
#     'team_PP%': 2.5,
#     'team_PK%': 0.0,
#     'team_GA': 0.0,
#     'team_G': 0.3,
#     'enemy_PEN/GP': 2.5,
#     'enemy_PP%': 0.0,
#     'enemy_PK%': 2.6,
#     'enemy_GA': 0.4,
#     'enemy_G': 0.0
# }

# df[features] = df[features].apply(lambda x: x + biases[x.name])

# 35 Features
features = ['ppPoints', 'gamesPlayed', 'position', 'ppUnit', 'avgPowerplayToi', 'team_G', 'team_GA', 'team_PP%', 'PPGF', 'PPG/PG', 'PPO/PG',
            'PPTOI/PG', 'PEN', 'PENMin', 'team_PEN/GP', 'PENSeconds/PG', 'PENDrawn/GP', 'PPGA', 'team_PK%', 'PKTIO/PG', 'enemy_G', 'enemy_GA', 'enemy_PP%',
            'PPGF_enemy', 'PPG/PG_enemy', 'PPO/PG_enemy', 'PPTOI/PG_enemy', 'PEN_enemy', 'PENMin_enemy', 'enemy_PEN/GP', 'PENSeconds/PG_enemy', 'PENDrawn/GP_enemy',
            'PPGA_enemy', 'enemy_PK%', 'PKTIO/PG_enemy']

# scaler = MinMaxScaler()
# scaler.fit(df[features])
# df[features] = scaler.transform(df[features])

scaler = StandardScaler()
scaler.fit(df[features])
df[features] = scaler.transform(df[features])

# df[features] = df[features].apply(lambda x: x + biases[x.name])

X = df[features].values
y = df['scored'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)

# Fit and transform the training data using the RandomUnderSampler
# X_train, y_train = undersampler.fit_resample(X_train, y_train)
X_train, y_train = oversampler.fit_resample(X_train, y_train)

X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

print(X_train.shape)

model = Sequential()
# model.add(Dense(256, activation='relu'))
# model.add(Dense(len(features), activation='sigmoid'))
model.add(Dense(512, activation='relu'))
# model.add(Dense(256, activation='relu'))
model.add(LSTM(256, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.keras.metrics.Precision()])
# model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=[tf.keras.metrics.Precision()])

tf.random.set_seed(42)
history = model.fit(X_train, y_train, epochs=65, batch_size=128, validation_data=(X_test, y_test), verbose=1, shuffle=True)
# history = model.fit(X_train, y_train, epochs=65, batch_size=512, verbose=1, shuffle=True)
# Out:
# (2694, 1, 35)
# Epoch 1/65
# 22/22 [==============================] - 2s 24ms/step - loss: 0.6560 - precision: 0.6081 - val_loss: 0.6713 - val_precision: 0.2680
# Epoch 2/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.6126 - precision: 0.6401 - val_loss: 0.6372 - val_precision: 0.2653
# Epoch 3/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5774 - precision: 0.6842 - val_loss: 0.6232 - val_precision: 0.3038
# Epoch 4/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5399 - precision: 0.7168 - val_loss: 0.5792 - val_precision: 0.3045
# Epoch 5/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4986 - precision: 0.7507 - val_loss: 0.6918 - val_precision: 0.2712
# Epoch 6/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4680 - precision: 0.7642 - val_loss: 0.5889 - val_precision: 0.3139
# Epoch 7/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4189 - precision: 0.7840 - val_loss: 0.5288 - val_precision: 0.3313
# Epoch 8/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.4078 - precision: 0.8067 - val_loss: 0.5736 - val_precision: 0.3415
# Epoch 9/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3552 - precision: 0.8411 - val_loss: 0.5740 - val_precision: 0.3654
# Epoch 10/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3109 - precision: 0.8595 - val_loss: 0.6363 - val_precision: 0.3585
# Epoch 11/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3028 - precision: 0.8527 - val_loss: 0.5342 - val_precision: 0.4118
# Epoch 12/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2773 - precision: 0.8746 - val_loss: 0.6354 - val_precision: 0.3981
# Epoch 13/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2444 - precision: 0.8855 - val_loss: 0.6017 - val_precision: 0.3961
# Epoch 14/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2844 - precision: 0.8855 - val_loss: 0.6000 - val_precision: 0.3852
# Epoch 15/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2512 - precision: 0.8882 - val_loss: 0.6349 - val_precision: 0.3793
# Epoch 16/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2248 - precision: 0.8985 - val_loss: 0.5779 - val_precision: 0.4167
# Epoch 17/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2015 - precision: 0.9002 - val_loss: 0.7482 - val_precision: 0.3785
# Epoch 18/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1766 - precision: 0.9161 - val_loss: 0.5753 - val_precision: 0.4636
# Epoch 19/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1613 - precision: 0.9258 - val_loss: 0.6410 - val_precision: 0.4628
# Epoch 20/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1603 - precision: 0.9294 - val_loss: 0.6190 - val_precision: 0.4437
# Epoch 21/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1405 - precision: 0.9292 - val_loss: 0.6644 - val_precision: 0.4258
# Epoch 22/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1549 - precision: 0.9279 - val_loss: 0.8826 - val_precision: 0.3816
# Epoch 23/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1657 - precision: 0.9289 - val_loss: 0.6679 - val_precision: 0.4500
# Epoch 24/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1356 - precision: 0.9333 - val_loss: 0.6771 - val_precision: 0.5128
# Epoch 25/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3542 - precision: 0.8876 - val_loss: 0.7062 - val_precision: 0.3902
# Epoch 26/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1919 - precision: 0.9053 - val_loss: 0.6087 - val_precision: 0.4583
# Epoch 27/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1579 - precision: 0.9269 - val_loss: 0.6736 - val_precision: 0.4173
# Epoch 28/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1741 - precision: 0.9245 - val_loss: 0.6570 - val_precision: 0.4610
# Epoch 29/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1878 - precision: 0.9079 - val_loss: 0.6580 - val_precision: 0.4457
# Epoch 30/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1339 - precision: 0.9375 - val_loss: 0.6527 - val_precision: 0.4691
# Epoch 31/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1312 - precision: 0.9347 - val_loss: 0.6904 - val_precision: 0.4384
# Epoch 32/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1083 - precision: 0.9461 - val_loss: 0.7023 - val_precision: 0.4710
# Epoch 33/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1060 - precision: 0.9474 - val_loss: 0.7415 - val_precision: 0.4557
# Epoch 34/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1016 - precision: 0.9486 - val_loss: 0.7698 - val_precision: 0.4702
# Epoch 35/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1283 - precision: 0.9370 - val_loss: 0.7893 - val_precision: 0.4762
# Epoch 36/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2034 - precision: 0.9174 - val_loss: 0.8085 - val_precision: 0.4233
# Epoch 37/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1228 - precision: 0.9389 - val_loss: 0.7413 - val_precision: 0.4485
# Epoch 38/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0998 - precision: 0.9562 - val_loss: 0.7194 - val_precision: 0.5105
# Epoch 39/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1134 - precision: 0.9519 - val_loss: 0.8563 - val_precision: 0.4031
# Epoch 40/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1093 - precision: 0.9442 - val_loss: 0.8234 - val_precision: 0.4122
# Epoch 41/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0893 - precision: 0.9502 - val_loss: 0.7988 - val_precision: 0.4568
# Epoch 42/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0845 - precision: 0.9552 - val_loss: 0.7874 - val_precision: 0.4924
# Epoch 43/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0916 - precision: 0.9547 - val_loss: 0.8711 - val_precision: 0.4392
# Epoch 44/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0833 - precision: 0.9577 - val_loss: 0.8444 - val_precision: 0.4662
# Epoch 45/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0783 - precision: 0.9597 - val_loss: 0.8808 - val_precision: 0.4242
# Epoch 46/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2288 - precision: 0.9076 - val_loss: 0.9838 - val_precision: 0.4070
# Epoch 47/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2556 - precision: 0.8835 - val_loss: 0.8205 - val_precision: 0.4896
# Epoch 48/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1789 - precision: 0.9296 - val_loss: 0.7926 - val_precision: 0.4365
# Epoch 49/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1585 - precision: 0.9404 - val_loss: 0.7325 - val_precision: 0.4765
# Epoch 50/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1014 - precision: 0.9480 - val_loss: 0.7519 - val_precision: 0.4481
# Epoch 51/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0834 - precision: 0.9591 - val_loss: 0.7923 - val_precision: 0.4362
# Epoch 52/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0867 - precision: 0.9543 - val_loss: 0.8243 - val_precision: 0.4348
# Epoch 53/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0758 - precision: 0.9586 - val_loss: 0.8525 - val_precision: 0.4375
# Epoch 54/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1060 - precision: 0.9555 - val_loss: 0.8449 - val_precision: 0.4507
# Epoch 55/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0873 - precision: 0.9616 - val_loss: 0.8518 - val_precision: 0.4390
# Epoch 56/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0700 - precision: 0.9627 - val_loss: 0.8771 - val_precision: 0.4400
# Epoch 57/65
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0681 - precision: 0.9648 - val_loss: 0.8280 - val_precision: 0.4714
# Epoch 58/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0644 - precision: 0.9655 - val_loss: 0.9076 - val_precision: 0.4444
# Epoch 59/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0638 - precision: 0.9668 - val_loss: 0.9600 - val_precision: 0.4424
# Epoch 60/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1846 - precision: 0.9224 - val_loss: 0.8454 - val_precision: 0.4793
# Epoch 61/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1012 - precision: 0.9578 - val_loss: 0.8938 - val_precision: 0.4321
# Epoch 62/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0969 - precision: 0.9559 - val_loss: 0.8498 - val_precision: 0.4321
# Epoch 63/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0747 - precision: 0.9635 - val_loss: 0.8283 - val_precision: 0.4741
# Epoch 64/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0640 - precision: 0.9641 - val_loss: 0.8516 - val_precision: 0.4526
# Epoch 65/65
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0644 - precision: 0.9642 - val_loss: 0.8773 - val_precision: 0.4459

# %%
from sklearn.metrics import classification_report

y_pred_probs = model.predict(X_test)

# Adjust the threshold
threshold = 0.9 # You can experiment with different threshold values
y_pred_labels = (y_pred_probs > threshold).astype(int)

print(f'threshold of {threshold*100}%')
print(classification_report(y_test, y_pred_labels))

y_pred = model.predict(X_test) 
y_pred = np.round(y_pred).astype(int)
print('Regular threshold')
print(classification_report(y_test, y_pred))
# Out:
# 22/22 [==============================] - 0s 1ms/step
# threshold of 90.0%
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       565
#            1       0.53      0.36      0.43       134
#
#     accuracy                           0.82       699
#    macro avg       0.69      0.64      0.66       699
# weighted avg       0.80      0.82      0.80       699
#
# 22/22 [==============================] - 0s 2ms/step
# Regular threshold
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87       565
#            1       0.45      0.49      0.47       134
#
#     accuracy                           0.79       699
#    macro avg       0.66      0.67      0.67       699
# weighted avg       0.79      0.79      0.79       699

# %%
# model.save('model.h5')

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['precision'], label='Training Precision')
# plt.plot(y_pred, label='Testing Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Player List Prediction

# %%
list_df = pd.read_csv('../../../lib/ai_bum_list.csv')

list_df.drop(list_df['skaterFullName'].loc[list_df['skaterFullName'] == 'Taylor Hall'].index, inplace=True)
list_df['avgPowerplayToi'] = list_df['avgPowerplayToi'].apply(lambda x: datetime.strptime(str(x), "%M:%S").second + datetime.strptime(str(x), "%M:%S").minute * 60)
list_df['position'].replace(['C', 'R', 'L', 'D'], [2, 2, 2, 1], inplace=True)

features = ['ppPoints', 'gamesPlayed', 'position', 'ppUnit', 'avgPowerplayToi', 'team_G', 'team_GA', 'team_PP%', 'PPGF', 'PPG/PG', 'PPO/PG',
            'PPTOI/PG', 'PEN', 'PENMin', 'team_PEN/GP', 'PENSeconds/PG', 'PENDrawn/GP', 'PPGA', 'team_PK%', 'PKTIO/PG', 'enemy_G', 'enemy_GA', 'enemy_PP%',
            'PPGF_enemy', 'PPG/PG_enemy', 'PPO/PG_enemy', 'PPTOI/PG_enemy', 'PEN_enemy', 'PENMin_enemy', 'enemy_PEN/GP', 'PENSeconds/PG_enemy', 'PENDrawn/GP_enemy',
            'PPGA_enemy', 'enemy_PK%', 'PKTIO/PG_enemy']

list_df[features] = scaler.transform(list_df[features])

# Iterate over each row and reshape
reshaped_data_list = []
for index, row in list_df.iterrows():
    reshaped_data = row[features].values.reshape(1, 1, 35)
    reshaped_data_list.append(reshaped_data)


# Convert the list to a NumPy array
reshaped_data_array = np.array(reshaped_data_list, dtype=np.float32)

predictions = []
for i in reshaped_data_array:
    pred = model.predict(i, verbose=0)
    predictions.append(pred[0][0])

# Return scaled data to normal
list_df['prediction'] = predictions

list_df[features] = scaler.inverse_transform(list_df[features])
list_df.sort_values(by='prediction', ascending=False).to_csv('rnn_preds.csv')

# %%
pred_list = pd.read_csv('rnn_preds.csv')


# display = ['skaterFullName', 'teamAbbrevs', 'ppPoints', 'ppUnit', 'team_PP%', 'vs', 'enemy_PP%', 'enemy_PK%', 'enemy_PEN/GP', 'prediction', 'odds']
display = ['skaterFullName', 'teamAbbrevs', 'ppPoints', 'ppUnit', 'team_PP%', 'vs', 'enemy_PP%', 'enemy_PK%', 'enemy_PEN/GP', 'prediction']

pred_list['prediction'] = pred_list['prediction'].apply(lambda x: round(x, 5))

# Grab only the top predictions based on the threshold
threshold = 0.5
top_threshold = pred_list[pred_list['prediction'] > threshold]


print(f'Threshold of {threshold*100}%')
# Out:
# Threshold of 50.0%

# %%
# odds = [
#     1.83,
#     2.30,
#     1.86,
#     2.55,
#     2.40,
#     7.0,
#     1.86,
#     2.90,
#     1.86,
#     3.90,
#     3.40
# ]

# top_threshold['odds'] = odds
top_threshold[display]
# Out:
# Empty DataFrame
# Columns: [skaterFullName, teamAbbrevs, ppPoints, ppUnit, team_PP%, vs, enemy_PP%, enemy_PK%, enemy_PEN/GP, prediction]
# Index: []
